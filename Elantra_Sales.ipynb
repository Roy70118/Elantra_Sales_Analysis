# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from sklearn import linear_model
import warnings
warnings.filterwarnings('ignore')

# %%
#car sales data
df=pd.read_csv("D:\TECHSTACK.py\TECHSTACK DATA\elantra.csv")
df.head()
# Out:
#    Month  Year  ElantraSales  Unemployment  Queries  CPI_energy  CPI_all
# 0      1  2010          7690           9.7      153     213.377  217.466
# 1      1  2011          9659           9.1      259     229.353  221.082
# 2      1  2012         10900           8.2      354     244.178  227.666
# 3      1  2013         12174           7.9      230     242.560  231.321
# 4      1  2014         15326           6.6      232     247.575  234.933

# %%
df
# Out:
#     Month  Year  ElantraSales  Unemployment  Queries  CPI_energy  CPI_all
# 0       1  2010          7690           9.7      153     213.377  217.466
# 1       1  2011          9659           9.1      259     229.353  221.082
# 2       1  2012         10900           8.2      354     244.178  227.666
# 3       1  2013         12174           7.9      230     242.560  231.321
# 4       1  2014         15326           6.6      232     247.575  234.933
# 5       2  2010          7966           9.8      130     209.924  217.251
# 6       2  2011         12289           9.0      266     232.188  221.816
# 7       2  2012         13820           8.3      296     247.615  228.138
# 8       2  2013         16219           7.7      239     252.639  232.599
# 9       2  2014         16393           6.7      240     246.389  235.169
# 10      3  2010          8225           9.9      138     209.163  217.305
# 11      3  2011         19255           9.0      281     239.454  222.955
# ...

# %%
y=df['ElantraSales']
y.head()
# Out:
# 0     7690
# 1     9659
# 2    10900
# 3    12174
# 4    15326
# Name: ElantraSales, dtype: int64

# %%
x=df.drop('ElantraSales',axis=1)
x.head()
# Out:
#    Month  Year  Unemployment  Queries  CPI_energy  CPI_all
# 0      1  2010           9.7      153     213.377  217.466
# 1      1  2011           9.1      259     229.353  221.082
# 2      1  2012           8.2      354     244.178  227.666
# 3      1  2013           7.9      230     242.560  231.321
# 4      1  2014           6.6      232     247.575  234.933

# %%
df.shape
# Out:
# (50, 7)

# %%
df.columns
# Out:
# Index(['Month', 'Year', 'ElantraSales', 'Unemployment', 'Queries',
#        'CPI_energy', 'CPI_all'],
#       dtype='object')

# %%
df.columns.nunique()
# Out:
# 7

# %%
x.shape
# Out:
# (50, 6)

# %%
x.columns.nunique()
# Out:
# 6

# %%
y
# Out:
# 0      7690
# 1      9659
# 2     10900
# 3     12174
# 4     15326
# 5      7966
# 6     12289
# 7     13820
# 8     16219
# 9     16393
# 10     8225
# 11    19255
# 12    19681
# 13    26153
# 14     9657
# 15    22100
# 16    16836
# 17    24445
# 18     9781
# 19    20006
# 20    18877
# 21    25090
# 22    14245
# 23    19992
# 24    17655
# 25    22163
# 26    18215
# 27    15181
# 28    18512
# 29    23958
# 30    15181
# 31    15054
# 32    17989
# 33    24700
# 34    10062
# 35    14386
# 36    18305
# 37    19691
# 38     9497
# 39    13000
# 40    14512
# 41    14876
# 42     8631
# 43    12414
# 44    15923
# 45    16751
# 46    13096
# 47    13025
# 48    19024
# 49    21692
# Name: ElantraSales, dtype: int64

# %%
x.hist(figsize = (12,12))
# Out:
# array([[<AxesSubplot:title={'center':'Month'}>,
#         <AxesSubplot:title={'center':'Year'}>],
#        [<AxesSubplot:title={'center':'Unemployment'}>,
#         <AxesSubplot:title={'center':'Queries'}>],
#        [<AxesSubplot:title={'center':'CPI_energy'}>,
#         <AxesSubplot:title={'center':'CPI_all'}>]], dtype=object)

# %%
sns.pairplot(x)

# %%
x.corr()
# Out:
#                  Month      Year  Unemployment   Queries  CPI_energy   CPI_all
# Month         1.000000 -0.113547     -0.066478  0.036977    0.097092  0.114893
# Year         -0.113547  1.000000     -0.972425  0.381183    0.714229  0.955978
# Unemployment -0.066478 -0.972425      1.000000 -0.349408   -0.701494 -0.963583
# Queries       0.036977  0.381183     -0.349408  1.000000    0.760016  0.508056
# CPI_energy    0.097092  0.714229     -0.701494  0.760016    1.000000  0.840991
# CPI_all       0.114893  0.955978     -0.963583  0.508056    0.840991  1.000000

# %%
sns.heatmap(x.corr())
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(df.CPI_all,df.ElantraSales,data=df,hue='ElantraSales', size='ElantraSales')
plt.show()

# %%
sns.lineplot(df.CPI_all,df.ElantraSales)
plt.show()

# %%
sns.regplot(df.CPI_all,df.ElantraSales)
# Out:
# <AxesSubplot:xlabel='CPI_all', ylabel='ElantraSales'>

# %%
sns.scatterplot(df.Unemployment,df.ElantraSales,data=df,hue='ElantraSales')
plt.show()

# %%
sns.regplot(df.Unemployment,df.ElantraSales)
plt.show()

# %%
sns.lineplot(df.Unemployment,df.ElantraSales)
# Out:
# <AxesSubplot:xlabel='Unemployment', ylabel='ElantraSales'>

# %%
sns.lineplot(df.Month,df.ElantraSales)
plt.show()

# %%
sns.barplot(df.Month,df.ElantraSales)
plt.show()

# %%
sns.barplot(df.Unemployment,df.ElantraSales)
plt.show()

# %%
sns.barplot(df.Year,df.ElantraSales)
plt.show()

# %%
sns.barplot(df.CPI_all,df.ElantraSales)
plt.show()

# %%
sns.barplot(df.CPI_energy,df.ElantraSales)
plt.show()

# %%
plt.scatter(df.index,df.ElantraSales)

# %%
plt.scatter(df.index,df.CPI_energy)

# %%
plt.scatter(df.index,df.CPI_all)

# %%
sns.regplot(df.Year,df.Unemployment)
plt.show()

# %%
sns.boxplot(x=x.Year,y=x.Unemployment,data=x)
plt.show()

# %%
sns.lineplot(df.Year,df.CPI_all)
plt.show()

# %%
sns.boxplot(df.Year,df.ElantraSales,data=x)
plt.show()

# %%
sns.boxplot(df.Year,df.CPI_all,data=x)
plt.show()

# %%
sns.boxplot(df.Year,df.CPI_energy,data=x)
plt.show()

# %%
sns.scatterplot(df.CPI_energy,df.ElantraSales)
plt.show()

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(y)
plt.show()

# %%
x.shape,y.shape
# Out:
# ((50, 6), (50,))

# %%
plt.scatter(y.index,y)

# %%
lm = linear_model.LinearRegression()

# %%
lm.fit(x,y)
# Out:
# LinearRegression()

# %%
pred = lm.predict(x)
print(pred)
print(pred.shape)
# Out:
# [ 8634.52337088 14947.49489244 17589.83727234 16842.99744936
#  20342.00190268  8660.84549208 14947.00141245 15985.09185132
#  16476.88126133 20761.02382107  9303.4689136  14746.8388179
#  16117.8689568  19635.40132291  9597.89954104 14802.90489413
#  17764.25734105 18660.19845694 11587.09741672 16462.07276629
#  16093.58836196 18880.73396821 11112.81411804 16640.82984081
#  16688.53098399 20576.93310485 11718.18246964 18164.69117084
#  21299.49714981 19487.29585807 13213.77691753 15462.46521427
#  18465.62811899 19767.1995618  12008.58761055 16045.09960116
#  18965.34491459 20725.48181445 12628.01152577 16894.80543244
#  15612.43420572 19073.03544407 11998.77390527 13878.89482548
#  16205.81470643 19628.56704029 12135.50162387 14379.38196271
#  17546.72148388 21107.66991112]
# (50,)

# %%
_score=lm.score(x,y)*100
_score
# Out:
# 49.66690264010673

# %%
pred = pd.DataFrame(pred)

# %%
plt.figure(figsize=(8,8))
plt.scatter(y.index, y ,label='Actual',color='b')
plt.plot(pred,label='predicted',color='r')
plt.title('Actual values VS Predictedd values')
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree = 3)

# %%
Ex=np.array([[2,3,4]])
Ex_poly=poly.fit_transform(Ex)
Ex_poly
# Out:
# array([[ 1.,  2.,  3.,  4.,  4.,  6.,  8.,  9., 12., 16.,  8., 12., 16.,
#         18., 24., 32., 27., 36., 48., 64.]])

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree = 3) 
x_poly = poly.fit_transform(x.iloc[:,0].values.reshape(-1,1)) 
lm = LinearRegression() 
lm.fit(x_poly, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-4e536b2c297b> in <module>
#       2 poly = PolynomialFeatures(degree = 3)
#       3 x_poly = poly.fit_transform(x.iloc[:,0].values.reshape(-1,1))
# ----> 4 lm = LinearRegression()
#       5 lm.fit(x_poly, y)
#
# NameError: name 'LinearRegression' is not defined

# %%
x_poly
# Out:
# array([[1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00],
#        [1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00],
#        [1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00],
#        [1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00],
#        [1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00],
#        [1.000e+00, 2.000e+00, 4.000e+00, 8.000e+00],
#        [1.000e+00, 2.000e+00, 4.000e+00, 8.000e+00],
#        [1.000e+00, 2.000e+00, 4.000e+00, 8.000e+00],
#        [1.000e+00, 2.000e+00, 4.000e+00, 8.000e+00],
#        [1.000e+00, 2.000e+00, 4.000e+00, 8.000e+00],
#        [1.000e+00, 3.000e+00, 9.000e+00, 2.700e+01],
#        [1.000e+00, 3.000e+00, 9.000e+00, 2.700e+01],
#        [1.000e+00, 3.000e+00, 9.000e+00, 2.700e+01],
#        [1.000e+00, 3.000e+00, 9.000e+00, 2.700e+01],
#        [1.000e+00, 4.000e+00, 1.600e+01, 6.400e+01],
#        [1.000e+00, 4.000e+00, 1.600e+01, 6.400e+01],
#        [1.000e+00, 4.000e+00, 1.600e+01, 6.400e+01],
#        [1.000e+00, 4.000e+00, 1.600e+01, 6.400e+01],
# ...

# %%
plt.scatter(x.iloc[:,0].values.reshape(-1,1), y, color = 'blue')   
plt.plot(x.iloc[:,0].values.reshape(-1,1), lin2.predict(poly.fit_transform(x.iloc[:,0].values.reshape(-1,1))), 'r--') 
plt.title('Polynomial Regression') 

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-6594793a5a37> in <module>
#       1 plt.scatter(x.iloc[:,0].values.reshape(-1,1), y, color = 'blue')
# ----> 2 plt.plot(x.iloc[:,0].values.reshape(-1,1), lin2.predict(poly.fit_transform(x.iloc[:,0].values.reshape(-1,1))), 'r--')
#       3 plt.title('Polynomial Regression')
#       4
#       5 plt.show()
#
# NameError: name 'lin2' is not defined
